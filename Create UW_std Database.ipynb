-- %%
--DROP DATABASE UW_std

USE master

IF EXISTS (SELECT name FROM sys.databases WHERE name = N'UW_std')
BEGIN
    PRINT 'UW_std database dropped '
    DROP DATABASE [UW_std];
END;

-- %%
--CREATE DATABASE UW_std

USE master

IF NOT EXISTS (SELECT name FROM sys.databases WHERE name = N'UW_std')
BEGIN
    PRINT 'Database created'
    CREATE DATABASE [UW_std];
END;

-- %%
-- CREATE and INSERT advisedBy

USE UW_std

DROP TABLE IF EXISTS advisedBy;

CREATE TABLE advisedBy (
  p_id int NOT NULL DEFAULT 0,
  p_id_dummy int NOT NULL DEFAULT 0
) ;

TRUNCATE TABLE advisedBy;

INSERT INTO advisedBy (p_id, p_id_dummy) VALUES
(96, 5),
(118, 5),
(183, 5),
(263, 5),
(362, 5),
(266, 7),
(272, 7),
(6, 29),
(242, 29),
(303, 29),
(159, 57),
(122, 72),
(157, 72),
(200, 72),
(206, 72),
(217, 72),
(404, 72),
(37, 79),
(275, 79),
(380, 79),
(67, 98),
(92, 101),
(155, 101),
(218, 101),
(253, 101),
(280, 101),
(419, 101),
(62, 104),
(89, 104),
(99, 104),
(100, 104),
(204, 104),
(376, 107),
(116, 124),
(130, 124),
(154, 124),
(357, 124),
(14, 150),
(320, 150),
(6, 165),
(242, 165),
(288, 165),
(303, 165),
(265, 168),
(381, 168),
(148, 171),
(239, 171),
(286, 171),
(418, 171),
(129, 179),
(374, 179),
(376, 179),
(426, 179),
(212, 180),
(368, 180),
(318, 185),
(68, 201),
(159, 201),
(21, 211),
(45, 211),
(126, 213),
(80, 234),
(129, 234),
(403, 234),
(100, 235),
(154, 235),
(391, 235),
(426, 235),
(13, 240),
(257, 240),
(384, 240),
(432, 240),
(435, 279),
(262, 292),
(352, 292),
(208, 319),
(312, 319),
(318, 319),
(353, 319),
(226, 324),
(348, 324),
(75, 331),
(141, 331),
(249, 331),
(9, 335),
(18, 335),
(362, 335),
(429, 335),
(81, 342),
(113, 342),
(142, 342),
(206, 342),
(217, 342),
(228, 342),
(300, 342),
(83, 349),
(411, 373),
(67, 375),
(309, 378),
(81, 393),
(163, 393),
(228, 393),
(41, 394),
(113, 394),
(228, 394),
(176, 407),
(276, 407),
(384, 407),
(45, 415),
(63, 415),
(262, 415),
(314, 415),
(352, 415);

PRINT 'Data Loaded';

-- %%
-- CREATE and INSERT course

USE UW_std

DROP TABLE IF EXISTS course;

CREATE TABLE course (
  course_id int NOT NULL,
  courseLevel varchar(40) DEFAULT NULL
) ;

TRUNCATE TABLE course;

INSERT INTO course (course_id, courseLevel) VALUES
(5, 'Level_300'),
(11, 'Level_300'),
(18, 'Level_300'),
(104, 'Level_300'),
(124, 'Level_300'),
(146, 'Level_300'),
(147, 'Level_300'),
(165, 'Level_300'),
(8, 'Level_400'),
(20, 'Level_400'),
(21, 'Level_400'),
(24, 'Level_400'),
(27, 'Level_400'),
(28, 'Level_400'),
(30, 'Level_400'),
(38, 'Level_400'),
(41, 'Level_400'),
(44, 'Level_400'),
(45, 'Level_400'),
(48, 'Level_400'),
(49, 'Level_400'),
(51, 'Level_400'),
(52, 'Level_400'),
(53, 'Level_400'),
(57, 'Level_400'),
(62, 'Level_400'),
(68, 'Level_400'),
(75, 'Level_400'),
(80, 'Level_400'),
(82, 'Level_400'),
(89, 'Level_400'),
(93, 'Level_400'),
(97, 'Level_400'),
(107, 'Level_400'),
(110, 'Level_400'),
(118, 'Level_400'),
(122, 'Level_400'),
(125, 'Level_400'),
(126, 'Level_400'),
(128, 'Level_400'),
(137, 'Level_400'),
(143, 'Level_400'),
(148, 'Level_400'),
(151, 'Level_400'),
(154, 'Level_400'),
(157, 'Level_400'),
(159, 'Level_400'),
(161, 'Level_400'),
(164, 'Level_400'),
(174, 'Level_400'),
(0, 'Level_500'),
(1, 'Level_500'),
(2, 'Level_500'),
(3, 'Level_500'),
(4, 'Level_500'),
(7, 'Level_500'),
(9, 'Level_500'),
(12, 'Level_500'),
(13, 'Level_500'),
(14, 'Level_500'),
(15, 'Level_500'),
(16, 'Level_500'),
(19, 'Level_500'),
(23, 'Level_500'),
(29, 'Level_500'),
(32, 'Level_500'),
(34, 'Level_500'),
(35, 'Level_500'),
(36, 'Level_500'),
(39, 'Level_500'),
(40, 'Level_500'),
(46, 'Level_500'),
(50, 'Level_500'),
(54, 'Level_500'),
(56, 'Level_500'),
(61, 'Level_500'),
(63, 'Level_500'),
(64, 'Level_500'),
(65, 'Level_500'),
(66, 'Level_500'),
(67, 'Level_500'),
(71, 'Level_500'),
(74, 'Level_500'),
(76, 'Level_500'),
(77, 'Level_500'),
(79, 'Level_500'),
(83, 'Level_500'),
(84, 'Level_500'),
(85, 'Level_500'),
(86, 'Level_500'),
(87, 'Level_500'),
(88, 'Level_500'),
(91, 'Level_500'),
(98, 'Level_500'),
(101, 'Level_500'),
(103, 'Level_500'),
(108, 'Level_500'),
(109, 'Level_500'),
(114, 'Level_500'),
(115, 'Level_500'),
(116, 'Level_500'),
(117, 'Level_500'),
(119, 'Level_500'),
(120, 'Level_500'),
(121, 'Level_500'),
(123, 'Level_500'),
(129, 'Level_500'),
(131, 'Level_500'),
(132, 'Level_500'),
(134, 'Level_500'),
(135, 'Level_500'),
(136, 'Level_500'),
(138, 'Level_500'),
(139, 'Level_500'),
(141, 'Level_500'),
(144, 'Level_500'),
(149, 'Level_500'),
(150, 'Level_500'),
(152, 'Level_500'),
(153, 'Level_500'),
(155, 'Level_500'),
(156, 'Level_500'),
(158, 'Level_500'),
(160, 'Level_500'),
(162, 'Level_500'),
(166, 'Level_500'),
(167, 'Level_500'),
(168, 'Level_500'),
(169, 'Level_500'),
(170, 'Level_500'),
(172, 'Level_500'),
(173, 'Level_500');

PRINT 'Data Loaded';

-- %%
-- CREATE and INSERT person

USE UW_std

DROP TABLE IF EXISTS person;

CREATE TABLE person (
  p_id int NOT NULL DEFAULT 0,
  professor varchar(11) NOT NULL DEFAULT '0',
  student varchar(11) NOT NULL DEFAULT '0',
  hasPosition varchar(11) NOT NULL DEFAULT '0',
'0', '1', '0', 'Pre_Quals', 'Year_1'),
(417, '0', '1', '0', 'Pre_Quals', 'Year_1'),
(418, '0', '1', '0', 'Post_Quals', 'Year_3'),
(419, '0', '1', '0', 'Post_Generals', 'Year_7'),
(420, '0', '1', '0', '0', '0'),
(422, '0', '1', '0', 'Post_Quals', 'Year_3'),
(424, '0', '1', '0', '0', '0'),
(426, '0', '1', '0', 'Post_Quals', 'Year_5'),
(427, '0', '1', '0', 'Post_Quals', 'Year_4'),
(428, '0', '1', '0', '0', '0'),
(429, '0', '1', '0', 'Post_Quals', 'Year_5'),
(431, '0', '1', '0', 'Pre_Quals', 'Year_2'),
(432, '0', '1', '0', 'Post_Quals', 'Year_5'),
(435, '0', '1', '0', 'Post_Quals', 'Year_4');

PRINT 'Data Loaded';

-- %%
-- CREATE and INSERT taughtBy

USE UW_std

DROP TABLE IF EXISTS taughtBy;

CREATE TABLE taughtBy (
  course_id int NOT NULL DEFAULT 0,
  p_id int NOT NULL DEFAULT 0
) ;

TRUNCATE TABLE taughtBy;

INSERT INTO taughtBy (course_id, p_id) VALUES
(0, 40),
(1, 40),
(2, 180),
(3, 279),
(4, 107),
(7, 415),
(8, 297),
(9, 235),
(11, 52),
(11, 57),
(11, 298),
(11, 324),
(11, 331),
(12, 79),
(12, 211),
(12, 407),
(13, 72),
(13, 342),
(14, 124),
(15, 292),
(16, 79),
(16, 240),
(18, 107),
(18, 213),
(18, 290),
(18, 326),
(18, 373),
(18, 375),
(19, 5),
(19, 370),
(20, 180),
(21, 22),
(21, 99),
(23, 179),
(24, 79),
(24, 150),
(24, 211),
(24, 240),
(24, 407),
(27, 165),
(27, 331),
(28, 394),
(29, 298),
(30, 290),
(32, 319),
(34, 179),
(36, 181),
(38, 104),
(38, 124),
(38, 204),
(38, 255),
(39, 415),
(40, 165),
(40, 298),
(40, 378),
(41, 351),
(44, 171),
(44, 293),
(44, 415),
(46, 335),
(48, 107),
(48, 213),
(48, 375),
(49, 64),
(49, 189),
(49, 248),
(49, 263),
(50, 171),
(51, 5),
(51, 18),
(51, 166),
(52, 168),
(53, 189),
(53, 248),
(57, 150),
(61, 107),
(62, 101),
(63, 335),
(64, 79),
(66, 165),
(66, 298),
(67, 394),
(68, 201),
(68, 324),
(68, 331),
(71, 5),
(74, 104),
(74, 124),
(75, 267),
(76, 319),
(77, 52),
(77, 165),
(77, 324),
(79, 72),
(80, 98),
(80, 101),
(80, 180),
(82, 407),
(84, 324),
(88, 235),
(89, 394),
(91, 331),
(93, 351),
(97, 324),
(98, 103),
(101, 279),
(101, 394),
(103, 201),
(104, 165),
(104, 181),
(104, 364),
(108, 279),
(110, 351),
(115, 72),
(115, 342),
(116, 375),
(117, 181),
(118, 351),
(119, 324),
(120, 82),
(120, 235),
(121, 52),
(122, 378),
(123, 150),
(124, 9),
(124, 46),
(124, 335),
(125, 351),
(126, 165),
(128, 150),
(129, 213),
(129, 373),
(132, 319),
(134, 240),
(136, 394),
(137, 165),
(138, 335),
(139, 235),
(141, 150),
(143, 211),
(143, 407),
(144, 278),
(144, 331),
(146, 335),
(147, 52),
(147, 57),
(147, 165),
(147, 201),
(147, 324),
(147, 331),
(147, 364),
(148, 351),
(149, 331),
(150, 351),
(151, 82),
(151, 179),
(151, 234),
(151, 235),
(151, 267),
(151, 290),
(153, 342),
(153, 394),
(156, 240),
(157, 72),
(157, 342),
(157, 394),
(158, 240),
(159, 394),
(160, 331),
(161, 201),
(161, 298),
(161, 331),
(162, 213),
(164, 351),
(165, 75),
(165, 141),
(165, 181),
(165, 231),
(165, 364),
(166, 235),
(167, 98),
(168, 240),
(170, 79),
(170, 211),
(170, 407),
(172, 46),
(172, 335),
(173, 171),
(174, 267);

PRINT 'Data Loaded';

-- %%
-- CREATE and ADD Keys, Indexes and Constraints

-- Indexes for table advisedBy
ALTER TABLE dbo.advisedBy
  ADD CONSTRAINT PK_advisedBy PRIMARY KEY CLUSTERED (p_id_dummy, p_id);
GO
CREATE NONCLUSTERED INDEX IX_advisedBy_p_id ON dbo.advisedBy(p_id);
GO
CREATE NONCLUSTERED INDEX IX_advisedBy_p_id_dummy ON dbo.advisedBy(p_id_dummy);
GO

-- Indexes for table course
ALTER TABLE dbo.course
  ADD CONSTRAINT PK_course PRIMARY KEY CLUSTERED (course_id);
GO
CREATE NONCLUSTERED INDEX IX_course_courseLevel ON dbo.course(courseLevel);
GO

-- Indexes for table person
ALTER TABLE dbo.person
  ADD CONSTRAINT PK_person PRIMARY KEY CLUSTERED (p_id);
GO
CREATE NONCLUSTERED INDEX IX_person_hasPosition ON dbo.person(hasPosition);
GO
CREATE NONCLUSTERED INDEX IX_person_inPhase ON dbo.person(inPhase);
GO
CREATE NONCLUSTERED INDEX IX_person_yearsInProgram ON dbo.person(yearsInProgram);
GO
CREATE NONCLUSTERED INDEX IX_person_professor ON dbo.person(professor);
GO
CREATE NONCLUSTERED INDEX IX_person_student ON dbo.person(student);
GO

-- Indexes for table taughtBy
ALTER TABLE dbo.taughtBy
  ADD CONSTRAINT PK_taughtBy PRIMARY KEY CLUSTERED (course_id, p_id);
GO
CREATE NONCLUSTERED INDEX IX_taughtBy_course_id ON dbo.taughtBy(course_id);
GO
CREATE NONCLUSTERED INDEX IX_taughtBy_p_id ON dbo.taughtBy(p_id);
GO

-- Constraints for table advisedBy
ALTER TABLE dbo.advisedBy
  ADD CONSTRAINT FK_advisedBy_person
    FOREIGN KEY (p_id)
    REFERENCES dbo.person(p_id)
    ON DELETE CASCADE
    ON UPDATE CASCADE;
GO

ALTER TABLE dbo.advisedBy
  ADD CONSTRAINT FK_advisedBy_person_dummy
    FOREIGN KEY (p_id_dummy)
    REFERENCES dbo.person(p_id)
    ON DELETE NO ACTION
    ON UPDATE NO ACTION;
GO

-- Constraints for table taughtBy
ALTER TABLE dbo.taughtBy
  ADD CONSTRAINT FK_taughtBy_course
    FOREIGN KEY (course_id)
    REFERENCES dbo.course(course_id)
    ON DELETE CASCADE
    ON UPDATE CASCADE;
GO

ALTER TABLE dbo.taughtBy
  ADD CONSTRAINT FK_taughtBy_person
    FOREIGN KEY (p_id)
    REFERENCES dbo.person(p_id)
    ON DELETE CASCADE
    ON UPDATE CASCADE;
GO
